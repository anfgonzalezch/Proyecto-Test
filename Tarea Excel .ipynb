# %%
#TareaExcel

import pandas as pd
df = pd.read_excel (r'C:\Users\H241509\Downloads\Base_Raw.xlsx')
#Para llamar un hoja de excel en específico es: df = pd.read_excel (archivo, sheet_name= 'NPT')
df.head ()
df.loc[0:4, :]
# Out:
#   CD_PROJECT.project_name CD_WELL.well_common_name      Contractor name  \
# 0                CASTILLA      CASTILLA DISPOSAL 3          HALLIBURTON
# 1                CASTILLA      CASTILLA DISPOSAL 3  PIONEER DE COLOMBIA
# 2                CASTILLA      CASTILLA DISPOSAL 3       ECOPETROL S.A.
# 3                CASTILLA      CASTILLA DISPOSAL 3                  NOV
# 4                CASTILLA      CASTILLA DISPOSAL 6   TUCKER CEMENTACION
#
#   Siglas del Evento*  Net time (hr) Total net cost ($)    code  \
# 0                ODR           70.5         193,869.13   DEFAL
# 1                ODR            1.0               0.00     RIG
# 2                ODR           27.5               0.00   DEFAL
# 3                ODR            4.0               0.00   DEFAL
# 4                ODR          109.5               0.00  CEMENT
#
#                      code_desc        Start date/time
# 0  DOWN HOLE EQUIPMENT FAILURE  7/15/2013 12:30:00 AM
# ...

# %%
import pandas as pd
df = pd.read_excel (r'C:\Users\H241509\Downloads\Base_Raw.xlsx')
df.head ()
df.loc[0:4, 'CD_PROJECT.project_name':'Contractor name']
# Out:
#   CD_PROJECT.project_name CD_WELL.well_common_name      Contractor name
# 0                CASTILLA      CASTILLA DISPOSAL 3          HALLIBURTON
# 1                CASTILLA      CASTILLA DISPOSAL 3  PIONEER DE COLOMBIA
# 2                CASTILLA      CASTILLA DISPOSAL 3       ECOPETROL S.A.
# 3                CASTILLA      CASTILLA DISPOSAL 3                  NOV
# 4                CASTILLA      CASTILLA DISPOSAL 6   TUCKER CEMENTACION

# %%
import pandas as pd
df = pd.read_excel (r'C:\Users\H241509\Downloads\Base_Raw.xlsx')
df.head ()
df.loc[0:4, ['CD_PROJECT.project_name', 'Contractor name']]
# Out:
#   CD_PROJECT.project_name      Contractor name
# 0                CASTILLA          HALLIBURTON
# 1                CASTILLA  PIONEER DE COLOMBIA
# 2                CASTILLA       ECOPETROL S.A.
# 3                CASTILLA                  NOV
# 4                CASTILLA   TUCKER CEMENTACION

# %%
import pandas as pd
df = pd.read_excel (r'C:\Users\H241509\Downloads\Base_Raw.xlsx')
df
#df.loc[df['CD_PROJECT.project_name']=='CASTILLA', :]
# Out:
#      CD_PROJECT.project_name CD_WELL.well_common_name  \
# 0                   CASTILLA      CASTILLA DISPOSAL 3
# 1                   CASTILLA      CASTILLA DISPOSAL 3
# 2                   CASTILLA      CASTILLA DISPOSAL 3
# 3                   CASTILLA      CASTILLA DISPOSAL 3
# 4                   CASTILLA      CASTILLA DISPOSAL 6
# ...                      ...                      ...
# 2694                CASTILLA             CASTILLA 604
# 2695                CASTILLA             CASTILLA 604
# 2696                CASTILLA             CASTILLA 604
# 2697                CASTILLA             CASTILLA 604
# 2698                CASTILLA             CASTILLA 604
#
#                 Contractor name Siglas del Evento*  Net time (hr)  \
# 0                   HALLIBURTON                ODR           70.5
# 1           PIONEER DE COLOMBIA                ODR            1.0
# 2                ECOPETROL S.A.                ODR           27.5
# ...

# %%
import pandas as pd
df = pd.read_excel (r'C:\Users\H241509\Downloads\Base_Raw.xlsx')
df.iloc[0:11, 0:4]
df.head ()
# Out:
#   CD_PROJECT.project_name CD_WELL.well_common_name      Contractor name  \
# 0                CASTILLA      CASTILLA DISPOSAL 3          HALLIBURTON
# 1                CASTILLA      CASTILLA DISPOSAL 3  PIONEER DE COLOMBIA
# 2                CASTILLA      CASTILLA DISPOSAL 3       ECOPETROL S.A.
# 3                CASTILLA      CASTILLA DISPOSAL 3                  NOV
# 4                CASTILLA      CASTILLA DISPOSAL 6   TUCKER CEMENTACION
#
#   Siglas del Evento*  Net time (hr) Total net cost ($)    code  \
# 0                ODR           70.5         193,869.13   DEFAL
# 1                ODR            1.0               0.00     RIG
# 2                ODR           27.5               0.00   DEFAL
# 3                ODR            4.0               0.00   DEFAL
# 4                ODR          109.5               0.00  CEMENT
#
#                      code_desc        Start date/time
# 0  DOWN HOLE EQUIPMENT FAILURE  7/15/2013 12:30:00 AM
# ...

# %%
import pandas as pd
df = pd.read_excel (r'C:\Users\H241509\Downloads\Base_Raw.xlsx')
print (df)
# Out:
#      CD_PROJECT.project_name CD_WELL.well_common_name  \
# 0                   CASTILLA      CASTILLA DISPOSAL 3
# 1                   CASTILLA      CASTILLA DISPOSAL 3
# 2                   CASTILLA      CASTILLA DISPOSAL 3
# 3                   CASTILLA      CASTILLA DISPOSAL 3
# 4                   CASTILLA      CASTILLA DISPOSAL 6
# ...                      ...                      ...
# 2694                CASTILLA             CASTILLA 604
# 2695                CASTILLA             CASTILLA 604
# 2696                CASTILLA             CASTILLA 604
# 2697                CASTILLA             CASTILLA 604
# 2698                CASTILLA             CASTILLA 604
#
#                 Contractor name Siglas del Evento*  Net time (hr)  \
# 0                   HALLIBURTON                ODR           70.5
# 1           PIONEER DE COLOMBIA                ODR            1.0
# 2                ECOPETROL S.A.                ODR           27.5
# ...

# %%
import pandas as pd
df = pd.read_excel (r'C:\Users\H241509\Downloads\Base_Raw.xlsx')
df.head ()
# Out:
#   CD_PROJECT.project_name CD_WELL.well_common_name      Contractor name  \
# 0                CASTILLA      CASTILLA DISPOSAL 3          HALLIBURTON
# 1                CASTILLA      CASTILLA DISPOSAL 3  PIONEER DE COLOMBIA
# 2                CASTILLA      CASTILLA DISPOSAL 3       ECOPETROL S.A.
# 3                CASTILLA      CASTILLA DISPOSAL 3                  NOV
# 4                CASTILLA      CASTILLA DISPOSAL 6   TUCKER CEMENTACION
#
#   Siglas del Evento*  Net time (hr) Total net cost ($)    code  \
# 0                ODR           70.5         193,869.13   DEFAL
# 1                ODR            1.0               0.00     RIG
# 2                ODR           27.5               0.00   DEFAL
# 3                ODR            4.0               0.00   DEFAL
# 4                ODR          109.5               0.00  CEMENT
#
#                      code_desc        Start date/time
# 0  DOWN HOLE EQUIPMENT FAILURE  7/15/2013 12:30:00 AM
# ...
